# %% [markdown]
# # Testing Regression on Attractiveness Data

# %% [markdown]
# ## Creating Facial Detection Function facial_detection(impath, margin)

# %%
from mtcnn import MTCNN
import PIL

def facial_detection(impath, margin):
    pixels = plt.imread(impath)
    img = PIL.Image.open(impath)
    
    detector = MTCNN()
    face = detector.detect_faces(pixels)

    box = face[0]["box"]

    # Original Face Shape
    x = max(box[0] - margin, 0)
    y = max(box[1] - margin, 0)
    width = min(box[2] + 2 * margin, img.width - x)
    height = min(box[3] + 2 * margin, img.height - y)

    center = (x + (width / 2), y + (height / 2))

    # Square Face Shape
    x = center[0] - (height / 2)
    y = center[1] - (height / 2)
    right = x + height
    bottom = y + height

    cropped_img = img.crop((x, y, right, bottom))
    return cropped_img

# %% [markdown]
# ## Regression Without Gender Stratification

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import pathlib
import PIL
# Out:
# WARNING:tensorflow:From C:\Users\gamer\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Retrieve Data

# %%
train_txt = "data/regression_train_test/train_ratings.txt"
test_txt = "data/regression_train_test/test_ratings.txt"

with open(train_txt) as train_ratings:
    train_ratings = train_ratings.readlines()[0]
    train_ratings = np.array(train_ratings.split())
    train_ratings = train_ratings.astype(float)

with open(test_txt) as test_ratings:
    test_ratings = test_ratings.readlines()[0]
    test_ratings = np.array(test_ratings.split())
    test_ratings = test_ratings.astype(float)

print(train_ratings)
print(test_ratings)
# Out:
# [3.433333 2.9      3.966667 ... 3.05     2.4      2.666667]
# [2.333333 3.45     2.7      ... 2.533333 4.433333 3.05    ]

# %%
img_width = 224
img_height = 224

# %%
import PIL

def image_to_tensor(impath):
    img = PIL.Image.open(impath).resize((img_width, img_height))
    img = np.array(img)
    tensor = tf.image.convert_image_dtype(img, dtype=tf.float16, saturate=False, name=None)
    return tensor

# %%
import pathlib

train_dir = pathlib.Path("data/all_images_cropped/")
test_dir = pathlib.Path("data/all_images_cropped/")

train_images = list(train_dir.glob("*_train/*.jpg"))
train_images = sorted(train_images, key=lambda x: str(x)[str(x).index("_train")+7:])
test_images = list(test_dir.glob("*_test/*.jpg"))
test_images = sorted(test_images, key=lambda x: str(x)[str(x).index("_test")+6:])

x_train = np.array([image_to_tensor(impath) for impath in train_images])
y_train = train_ratings

x_test = np.array([image_to_tensor(impath) for impath in test_images])
y_test = test_ratings

# %% [markdown]
# ### Make and Train ResNet152 Model

# %%
base_model = tf.keras.applications.ResNet152(input_shape=(img_width, img_height, 3), include_top=False, weights="imagenet")
base_model.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1, activation="linear")
])

model.compile(optimizer="adam", loss="mean_squared_error", metrics=["MeanAbsoluteError"])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 7, 7, 2048)        58370944
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 58372993 (222.68 MB)
# Trainable params: 2049 (8.00 KB)
# Non-trainable params: 58370944 (222.67 MB)
# _________________________________________________________________

# %%
# Smaller batch size because I was having an "exploding gradient" problem and I read that smaller batch sizes may help.
history = model.fit(x_train, y_train, batch_size=16, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 207/207 [==============================] - 1003s 5s/step - loss: 0.9541 - mean_absolute_error: 0.7011 - val_loss: 0.4117 - val_mean_absolute_error: 0.5306
# Epoch 2/10
# 207/207 [==============================] - 898s 4s/step - loss: 0.4307 - mean_absolute_error: 0.5367 - val_loss: 0.4009 - val_mean_absolute_error: 0.5232
# Epoch 3/10
# 207/207 [==============================] - 920s 4s/step - loss: 0.4175 - mean_absolute_error: 0.5253 - val_loss: 0.3817 - val_mean_absolute_error: 0.4998
# Epoch 4/10
# 207/207 [==============================] - 928s 4s/step - loss: 0.4110 - mean_absolute_error: 0.5196 - val_loss: 0.3720 - val_mean_absolute_error: 0.4912
# Epoch 5/10
# 207/207 [==============================] - 934s 5s/step - loss: 0.3996 - mean_absolute_error: 0.5104 - val_loss: 0.3775 - val_mean_absolute_error: 0.4832
# Epoch 6/10
# 207/207 [==============================] - 956s 5s/step - loss: 0.3883 - mean_absolute_error: 0.5005 - val_loss: 0.3619 - val_mean_absolute_error: 0.4791
# Epoch 7/10
# 207/207 [==============================] - 1238s 6s/step - loss: 0.3840 - mean_absolute_error: 0.4976 - val_loss: 0.3761 - val_mean_absolute_error: 0.4786
# Epoch 8/10
# 207/207 [==============================] - 1032s 5s/step - loss: 0.3836 - mean_absolute_error: 0.4965 - val_loss: 0.3529 - val_mean_absolute_error: 0.4740
# Epoch 9/10
# 207/207 [==============================] - 481s 2s/step - loss: 0.3770 - mean_absolute_error: 0.4911 - val_loss: 0.3509 - val_mean_absolute_error: 0.4681
# Epoch 10/10
# 207/207 [==============================] - 411s 2s/step - loss: 0.3827 - mean_absolute_error: 0.4923 - val_loss: 0.3498 - val_mean_absolute_error: 0.4661

# %%
model.save("models/nostrat_regression")
# Out:
# INFO:tensorflow:Assets written to: models/nostrat_regression\assets
# INFO:tensorflow:Assets written to: models/nostrat_regression\assets

# %%
def plot_reg_history(history):
    plt.figure(figsize=(8, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['mean_absolute_error'])
    plt.plot(history.history['val_mean_absolute_error'])
    plt.title('Model Mean Absolute Error')
    plt.ylabel('Mean Absolute Error')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()

# %%
plot_reg_history(history)

# %%
def predict_another(impath):
    img = facial_detection(impath, 10).resize((img_width, img_height))
    tensor = tf.image.convert_image_dtype(img, dtype=tf.float16, saturate=False, name=None)
    img_array = np.array([tensor])
    prediction = model.predict(img_array)
    prediction = float(prediction[0][0])
    print(f"This person is most likely a {round(prediction, 2)}")

    return img

# %%
def predict_scut(impath):
    img = PIL.Image.open(impath).resize((img_width, img_height))
    path = pathlib.Path(impath)
    index = test_images.index(path)
    actual_rating = test_ratings[index]
    
    tensor = tf.image.convert_image_dtype(img, dtype=tf.float16, saturate=False, name=None)
    img_array = np.array([tensor])
    prediction = model.predict(img_array)
    prediction = float(prediction[0][0])
    print(f"This person is most likely a {round(prediction, 2)}")
    print(f"Actual rating: {actual_rating}")

    return img

# %%
img = predict_another("data/my_images/timothee.jpg")
img
# Out:
# 1/1 [==============================] - 0s 211ms/step
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002263C6B7920> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 21ms/step
# 11/11 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 3s 3s/step
# This person is most likely a 3.49
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
scut_img = predict_scut("data/all_images_cropped/m_test/CM747.jpg")
scut_img
# Out:
# 1/1 [==============================] - 0s 219ms/step
# This person is most likely a 3.19
# Actual rating: 3.85
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# Let's see if 10 more epochs can get better results

# %%
model = tf.keras.models.load_model('models/nostrat_regression')

# %%
loss, mae = model.evaluate(x_test, y_test)
print("MAE on test data:", mae)
# Out:
# WARNING:tensorflow:From C:\Users\gamer\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 69/69 [==============================] - 385s 6s/step - loss: 0.3498 - mean_absolute_error: 0.4661
# MAE on test data: 0.4661300480365753

# %%
history2 = model.fit(x_train, y_train, batch_size=16, epochs=20, initial_epoch=10, validation_data=(x_test, y_test))
# Out:
# Epoch 11/20
# 207/207 [==============================] - 1890s 9s/step - loss: 0.3763 - mean_absolute_error: 0.4893 - val_loss: 0.3755 - val_mean_absolute_error: 0.4991
# Epoch 12/20
# 207/207 [==============================] - 977s 5s/step - loss: 0.3709 - mean_absolute_error: 0.4848 - val_loss: 0.3540 - val_mean_absolute_error: 0.4649
# Epoch 13/20
# 207/207 [==============================] - 976s 5s/step - loss: 0.3613 - mean_absolute_error: 0.4780 - val_loss: 0.3709 - val_mean_absolute_error: 0.4743
# Epoch 14/20
# 207/207 [==============================] - 17670s 86s/step - loss: 0.3723 - mean_absolute_error: 0.4845 - val_loss: 0.3492 - val_mean_absolute_error: 0.4750
# Epoch 15/20
# 207/207 [==============================] - -12162s -59049481us/step - loss: 0.3600 - mean_absolute_error: 0.4766 - val_loss: 0.3422 - val_mean_absolute_error: 0.4675
# Epoch 16/20
# 207/207 [==============================] - 932s 5s/step - loss: 0.3640 - mean_absolute_error: 0.4785 - val_loss: 0.3396 - val_mean_absolute_error: 0.4656
# Epoch 17/20
# 207/207 [==============================] - 38611s 187s/step - loss: 0.3507 - mean_absolute_error: 0.4697 - val_loss: 0.3366 - val_mean_absolute_error: 0.4536
# Epoch 18/20
# 207/207 [==============================] - 1011s 5s/step - loss: 0.3524 - mean_absolute_error: 0.4691 - val_loss: 0.3322 - val_mean_absolute_error: 0.4575
# Epoch 19/20
# 207/207 [==============================] - 1016s 5s/step - loss: 0.3505 - mean_absolute_error: 0.4680 - val_loss: 0.3324 - val_mean_absolute_error: 0.4519
# Epoch 20/20
# 207/207 [==============================] - 996s 5s/step - loss: 0.3494 - mean_absolute_error: 0.4656 - val_loss: 0.3455 - val_mean_absolute_error: 0.4728

# %%
plot_reg_history(history2)

# %% [markdown]
# The MAE and loss is still steadily decreasing, so more epochs may decrease the MAE even further. The MAE on the validation data however made it down to 0.4519 in the penultimate epoch, which is quite good.

# %%
model.save("models/nostrat_regression_20e")
# Out:
# INFO:tensorflow:Assets written to: models/nostrat_regression_20e\assets
# INFO:tensorflow:Assets written to: models/nostrat_regression_20e\assets

# %%
history3 = model.fit(x_train, y_train, batch_size=16, epochs=30, initial_epoch=20, validation_data=(x_test, y_test))
# Out:
# Epoch 21/30
# 207/207 [==============================] - 806s 4s/step - loss: 0.3525 - mean_absolute_error: 0.4707 - val_loss: 0.3460 - val_mean_absolute_error: 0.4737
# Epoch 22/30
# 207/207 [==============================] - 516s 2s/step - loss: 0.3419 - mean_absolute_error: 0.4624 - val_loss: 0.3304 - val_mean_absolute_error: 0.4576
# Epoch 23/30
# 207/207 [==============================] - 643s 3s/step - loss: 0.3485 - mean_absolute_error: 0.4681 - val_loss: 0.3313 - val_mean_absolute_error: 0.4492
# Epoch 24/30
# 207/207 [==============================] - 945s 5s/step - loss: 0.3446 - mean_absolute_error: 0.4647 - val_loss: 0.3234 - val_mean_absolute_error: 0.4495
# Epoch 25/30
# 207/207 [==============================] - 989s 5s/step - loss: 0.3457 - mean_absolute_error: 0.4642 - val_loss: 0.3761 - val_mean_absolute_error: 0.4754
# Epoch 26/30
# 207/207 [==============================] - 1006s 5s/step - loss: 0.3454 - mean_absolute_error: 0.4658 - val_loss: 0.3262 - val_mean_absolute_error: 0.4548
# Epoch 27/30
# 207/207 [==============================] - 680s 3s/step - loss: 0.3397 - mean_absolute_error: 0.4598 - val_loss: 0.3548 - val_mean_absolute_error: 0.4633
# Epoch 28/30
# 207/207 [==============================] - 425s 2s/step - loss: 0.3345 - mean_absolute_error: 0.4583 - val_loss: 0.3194 - val_mean_absolute_error: 0.4463
# Epoch 29/30
# 207/207 [==============================] - 407s 2s/step - loss: 0.3385 - mean_absolute_error: 0.4589 - val_loss: 0.3189 - val_mean_absolute_error: 0.4465
# Epoch 30/30
# 207/207 [==============================] - 413s 2s/step - loss: 0.3334 - mean_absolute_error: 0.4563 - val_loss: 0.3283 - val_mean_absolute_error: 0.4583

# %%
model.save("models/nostrat_regression_30e")
# Out:
# INFO:tensorflow:Assets written to: models/nostrat_regression_30e\assets
# INFO:tensorflow:Assets written to: models/nostrat_regression_30e\assets

# %%
plot_reg_history(history3)

# %%
img = predict_another("data/my_images/kylie.jpg")
img
# Out:
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 6ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 297ms/step
# This person is most likely a 3.56
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# Interesting that it the MAE still steadily going down still even after 30 epochs. Training these takes quite a bit of time though, so I'll stop here at this decent MAE and see if gender stratification can have a lower MAE with less epochs.

# %% [markdown]
# ## Regression With Gender Stratification

# %%
img_height = 224
img_width = 224

# %% [markdown]
# ### Retrieve Data

# %%
# Just so that the img_height & img_width update
def image_to_tensor(impath):
    img = PIL.Image.open(impath).resize((img_width, img_height))
    img = np.array(img)
    tensor = tf.image.convert_image_dtype(img, dtype=tf.float16, saturate=False, name=None)
    return tensor

# %%
def extract_ratings(text_path):
    with open(text_path) as ratings:
        ratings = ratings.readlines()[0]
        ratings = np.array(ratings.split())
        ratings = ratings.astype(float)

    return ratings

# %%
m_train_txt = "data/all_images_cropped/m_train_ratings"
f_train_txt = "data/all_images_cropped/f_train_ratings"

m_train_ratings = extract_ratings(m_train_txt)
f_train_ratings = extract_ratings(f_train_txt)

# %%
m_test_txt = "data/all_images_cropped/m_test_ratings"
f_test_txt = "data/all_images_cropped/f_test_ratings"

m_test_ratings = extract_ratings(m_test_txt)
f_test_ratings = extract_ratings(f_test_txt)

# %%
m_train_dir = pathlib.Path("data/all_images_cropped/m_train")
f_train_dir = pathlib.Path("data/all_images_cropped/f_train")
m_test_dir = pathlib.Path("data/all_images_cropped/m_test")
f_test_dir = pathlib.Path("data/all_images_cropped/f_test")

m_train_images = list(m_train_dir.glob("*.jpg"))
f_train_images = list(f_train_dir.glob("*.jpg"))
m_test_images = list(m_test_dir.glob("*.jpg"))
f_test_images = list(f_test_dir.glob("*.jpg"))

m_x_train = np.array([image_to_tensor(impath) for impath in m_train_images])
m_y_train = m_train_ratings

f_x_train = np.array([image_to_tensor(impath) for impath in f_train_images])
f_y_train = f_train_ratings

m_x_test = np.array([image_to_tensor(impath) for impath in m_test_images])
m_y_test = m_test_ratings

f_x_test = np.array([image_to_tensor(impath) for impath in f_test_images])
f_y_test = f_test_ratings

# %% [markdown]
# ### ResNet152 Model on Male Only Data

# %%
m_base_model = tf.keras.applications.ResNet152(input_shape=(img_width, img_height, 3), include_top=False, weights="imagenet")
m_base_model.trainable = False

m_model = tf.keras.Sequential([
    m_base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1, activation="linear")
])

m_model.compile(optimizer="adam", loss="mean_squared_error", metrics=["MeanAbsoluteError"])

# %%
m_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 7, 7, 2048)        58370944
#
#  global_average_pooling2d_1  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 58372993 (222.68 MB)
# Trainable params: 2049 (8.00 KB)
# Non-trainable params: 58370944 (222.67 MB)
# _________________________________________________________________

# %%
m_history = m_model.fit(m_x_train, m_y_train, batch_size=32, epochs=40, validation_data=(m_x_test, m_y_test))
# Out:
# Epoch 1/40
# 51/51 [==============================] - 292s 6s/step - loss: 1.1614 - mean_absolute_error: 0.8295 - val_loss: 0.4638 - val_mean_absolute_error: 0.4905
# Epoch 2/40
# 51/51 [==============================] - 268s 5s/step - loss: 0.4216 - mean_absolute_error: 0.5086 - val_loss: 0.3929 - val_mean_absolute_error: 0.4803
# Epoch 3/40
# 51/51 [==============================] - 267s 5s/step - loss: 0.4087 - mean_absolute_error: 0.5047 - val_loss: 0.3796 - val_mean_absolute_error: 0.4873
# Epoch 4/40
# 51/51 [==============================] - 262s 5s/step - loss: 0.4036 - mean_absolute_error: 0.4991 - val_loss: 0.3723 - val_mean_absolute_error: 0.4878
# Epoch 5/40
# 51/51 [==============================] - 261s 5s/step - loss: 0.3949 - mean_absolute_error: 0.4977 - val_loss: 0.3729 - val_mean_absolute_error: 0.4659
# Epoch 6/40
# 51/51 [==============================] - 273s 5s/step - loss: 0.3878 - mean_absolute_error: 0.4886 - val_loss: 0.3613 - val_mean_absolute_error: 0.4851
# Epoch 7/40
# 51/51 [==============================] - 265s 5s/step - loss: 0.3789 - mean_absolute_error: 0.4857 - val_loss: 0.3534 - val_mean_absolute_error: 0.4739
# Epoch 8/40
# 51/51 [==============================] - 268s 5s/step - loss: 0.3765 - mean_absolute_error: 0.4831 - val_loss: 0.3490 - val_mean_absolute_error: 0.4732
# Epoch 9/40
# 51/51 [==============================] - 282s 6s/step - loss: 0.3672 - mean_absolute_error: 0.4775 - val_loss: 0.3454 - val_mean_absolute_error: 0.4546
# Epoch 10/40
# 51/51 [==============================] - 286s 6s/step - loss: 0.3645 - mean_absolute_error: 0.4716 - val_loss: 0.3411 - val_mean_absolute_error: 0.4525
# Epoch 11/40
# 51/51 [==============================] - 267s 5s/step - loss: 0.3588 - mean_absolute_error: 0.4709 - val_loss: 0.3389 - val_mean_absolute_error: 0.4680
# Epoch 12/40
# 51/51 [==============================] - 262s 5s/step - loss: 0.3573 - mean_absolute_error: 0.4695 - val_loss: 0.3414 - val_mean_absolute_error: 0.4459
# Epoch 13/40
# 51/51 [==============================] - 273s 5s/step - loss: 0.3503 - mean_absolute_error: 0.4629 - val_loss: 0.3298 - val_mean_absolute_error: 0.4560
# Epoch 14/40
# 51/51 [==============================] - 276s 5s/step - loss: 0.3479 - mean_absolute_error: 0.4604 - val_loss: 0.3279 - val_mean_absolute_error: 0.4452
# Epoch 15/40
# 51/51 [==============================] - 275s 5s/step - loss: 0.3511 - mean_absolute_error: 0.4669 - val_loss: 0.3243 - val_mean_absolute_error: 0.4477
# Epoch 16/40
# 51/51 [==============================] - 285s 6s/step - loss: 0.3456 - mean_absolute_error: 0.4603 - val_loss: 0.3287 - val_mean_absolute_error: 0.4405
# Epoch 17/40
# 51/51 [==============================] - 255s 5s/step - loss: 0.3476 - mean_absolute_error: 0.4608 - val_loss: 0.3208 - val_mean_absolute_error: 0.4452
# Epoch 18/40
# 51/51 [==============================] - 260s 5s/step - loss: 0.3419 - mean_absolute_error: 0.4611 - val_loss: 0.3291 - val_mean_absolute_error: 0.4384
# Epoch 19/40
# 51/51 [==============================] - 267s 5s/step - loss: 0.3349 - mean_absolute_error: 0.4511 - val_loss: 0.3347 - val_mean_absolute_error: 0.4391
# Epoch 20/40
# 51/51 [==============================] - 274s 5s/step - loss: 0.3396 - mean_absolute_error: 0.4562 - val_loss: 0.3198 - val_mean_absolute_error: 0.4370
# Epoch 21/40
# 51/51 [==============================] - 270s 5s/step - loss: 0.3348 - mean_absolute_error: 0.4515 - val_loss: 0.3196 - val_mean_absolute_error: 0.4507
# Epoch 22/40
# 51/51 [==============================] - 280s 6s/step - loss: 0.3310 - mean_absolute_error: 0.4484 - val_loss: 0.3172 - val_mean_absolute_error: 0.4358
# Epoch 23/40
# 51/51 [==============================] - 262s 5s/step - loss: 0.3307 - mean_absolute_error: 0.4490 - val_loss: 0.3148 - val_mean_absolute_error: 0.4425
# Epoch 24/40
# 51/51 [==============================] - 259s 5s/step - loss: 0.3273 - mean_absolute_error: 0.4466 - val_loss: 0.3136 - val_mean_absolute_error: 0.4368
# Epoch 25/40
# 51/51 [==============================] - 256s 5s/step - loss: 0.3252 - mean_absolute_error: 0.4438 - val_loss: 0.3224 - val_mean_absolute_error: 0.4338
# Epoch 26/40
# 51/51 [==============================] - 274s 5s/step - loss: 0.3251 - mean_absolute_error: 0.4436 - val_loss: 0.3118 - val_mean_absolute_error: 0.4376
# Epoch 27/40
# 51/51 [==============================] - 277s 5s/step - loss: 0.3226 - mean_absolute_error: 0.4415 - val_loss: 0.3122 - val_mean_absolute_error: 0.4332
# Epoch 28/40
# 51/51 [==============================] - 279s 6s/step - loss: 0.3245 - mean_absolute_error: 0.4434 - val_loss: 0.3109 - val_mean_absolute_error: 0.4336
# Epoch 29/40
# 51/51 [==============================] - 272s 5s/step - loss: 0.3205 - mean_absolute_error: 0.4410 - val_loss: 0.3101 - val_mean_absolute_error: 0.4331
# Epoch 30/40
# 51/51 [==============================] - 273s 5s/step - loss: 0.3206 - mean_absolute_error: 0.4419 - val_loss: 0.3176 - val_mean_absolute_error: 0.4308
# Epoch 31/40
# 51/51 [==============================] - 273s 5s/step - loss: 0.3265 - mean_absolute_error: 0.4461 - val_loss: 0.3164 - val_mean_absolute_error: 0.4304
# Epoch 32/40
# 51/51 [==============================] - 271s 5s/step - loss: 0.3202 - mean_absolute_error: 0.4412 - val_loss: 0.3187 - val_mean_absolute_error: 0.4307
# Epoch 33/40
# 51/51 [==============================] - 272s 5s/step - loss: 0.3201 - mean_absolute_error: 0.4427 - val_loss: 0.3076 - val_mean_absolute_error: 0.4312
# Epoch 34/40
# 51/51 [==============================] - 261s 5s/step - loss: 0.3183 - mean_absolute_error: 0.4378 - val_loss: 0.3152 - val_mean_absolute_error: 0.4292
# Epoch 35/40
# 51/51 [==============================] - 241s 5s/step - loss: 0.3226 - mean_absolute_error: 0.4438 - val_loss: 0.3077 - val_mean_absolute_error: 0.4368
# Epoch 36/40
# 51/51 [==============================] - 242s 5s/step - loss: 0.3145 - mean_absolute_error: 0.4377 - val_loss: 0.3149 - val_mean_absolute_error: 0.4283
# Epoch 37/40
# 51/51 [==============================] - 242s 5s/step - loss: 0.3185 - mean_absolute_error: 0.4402 - val_loss: 0.3060 - val_mean_absolute_error: 0.4282
# Epoch 38/40
# 51/51 [==============================] - 243s 5s/step - loss: 0.3158 - mean_absolute_error: 0.4388 - val_loss: 0.3078 - val_mean_absolute_error: 0.4262
# Epoch 39/40
# 51/51 [==============================] - 242s 5s/step - loss: 0.3166 - mean_absolute_error: 0.4400 - val_loss: 0.3222 - val_mean_absolute_error: 0.4312
# Epoch 40/40
# 51/51 [==============================] - 242s 5s/step - loss: 0.3198 - mean_absolute_error: 0.4414 - val_loss: 0.3233 - val_mean_absolute_error: 0.4316

# %%
plot_reg_history(m_history)

# %%
def predict_another_male(impath):
    img = facial_detection(impath, 10).resize((img_width, img_height))
    tensor = tf.image.convert_image_dtype(img, dtype=tf.float16, saturate=False, name=None)
    img_array = np.array([tensor])
    prediction = m_model.predict(img_array)
    prediction = float(prediction[0][0])
    print(f"This person is most likely a {round(prediction, 2)}")

    return img

# %%
def predict_scut_male(impath):
    img = PIL.Image.open(impath).resize((img_width, img_height))
    path = pathlib.Path(impath)
    index = m_test_images.index(path)
    m_actual_rating = m_test_ratings[index]
    
    tensor = tf.image.convert_image_dtype(img, dtype=tf.float16, saturate=False, name=None)
    img_array = np.array([tensor])
    prediction = m_model.predict(img_array)
    prediction = float(prediction[0][0])
    print(f"This person is most likely a {round(prediction, 2)}")
    print(f"Actual rating: {m_actual_rating}")

    return img

# %%
path = pathlib.Path(r"data/all_images_cropped/m_test/CM667.jpg")

m_img = predict_scut_male(path)
m_img
# Out:
# 1/1 [==============================] - 1s 779ms/step
# This person is most likely a 3.32
# Actual rating: 4.333333
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ### ResNet152 Model on Female Only Data

# %%
f_base_model = tf.keras.applications.ResNet152(input_shape=(img_width, img_height, 3), include_top=False, weights="imagenet")
f_base_model.trainable = False

f_model = tf.keras.Sequential([
    f_base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1, activation="linear")
])

f_model.compile(optimizer="adam", loss="mean_squared_error", metrics=["MeanAbsoluteError"])

# %%
f_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152 (Functional)      (None, 7, 7, 2048)        58370944
#
#  global_average_pooling2d_2  (None, 2048)              0
#   (GlobalAveragePooling2D)
#
#  dense_9 (Dense)             (None, 1)                 2049
#
# =================================================================
# Total params: 58372993 (222.68 MB)
# Trainable params: 2049 (8.00 KB)
# Non-trainable params: 58370944 (222.67 MB)
# _________________________________________________________________

# %%
f_history = f_model.fit(f_x_train, f_y_train, batch_size=32, epochs=40, validation_data=(f_x_test, f_y_test))
# Out:
# Epoch 1/40
# 53/53 [==============================] - 254s 5s/step - loss: 1.6668 - mean_absolute_error: 0.9770 - val_loss: 0.4927 - val_mean_absolute_error: 0.5635
# Epoch 2/40
# 53/53 [==============================] - 243s 5s/step - loss: 0.4817 - mean_absolute_error: 0.5679 - val_loss: 0.4537 - val_mean_absolute_error: 0.5485
# Epoch 3/40
# 53/53 [==============================] - 242s 5s/step - loss: 0.4658 - mean_absolute_error: 0.5618 - val_loss: 0.4481 - val_mean_absolute_error: 0.5504
# Epoch 4/40
# 53/53 [==============================] - 248s 5s/step - loss: 0.4629 - mean_absolute_error: 0.5600 - val_loss: inf - val_mean_absolute_error: 564907708073300929455640914427904.0000
# Epoch 5/40
# 53/53 [==============================] - 251s 5s/step - loss: 0.4548 - mean_absolute_error: 0.5553 - val_loss: 0.4368 - val_mean_absolute_error: 0.5434
# Epoch 6/40
# 53/53 [==============================] - 243s 5s/step - loss: 0.4517 - mean_absolute_error: 0.5550 - val_loss: 0.4331 - val_mean_absolute_error: 0.5419
# Epoch 7/40
# 53/53 [==============================] - 239s 5s/step - loss: 0.4463 - mean_absolute_error: 0.5514 - val_loss: 0.4291 - val_mean_absolute_error: 0.5390
# Epoch 8/40
# 53/53 [==============================] - 239s 5s/step - loss: 0.4419 - mean_absolute_error: 0.5477 - val_loss: 0.4290 - val_mean_absolute_error: 0.5354
# Epoch 9/40
# 53/53 [==============================] - 240s 5s/step - loss: 0.4391 - mean_absolute_error: 0.5434 - val_loss: 0.4208 - val_mean_absolute_error: 0.5321
# Epoch 10/40
# 53/53 [==============================] - 242s 5s/step - loss: 0.4344 - mean_absolute_error: 0.5439 - val_loss: 0.4186 - val_mean_absolute_error: 0.5316
# Epoch 11/40
# 53/53 [==============================] - 242s 5s/step - loss: 0.4333 - mean_absolute_error: 0.5417 - val_loss: 0.4145 - val_mean_absolute_error: 0.5275
# Epoch 12/40
# 53/53 [==============================] - 243s 5s/step - loss: 0.4302 - mean_absolute_error: 0.5376 - val_loss: 0.4148 - val_mean_absolute_error: 0.5280
# Epoch 13/40
# 53/53 [==============================] - 244s 5s/step - loss: 0.4237 - mean_absolute_error: 0.5337 - val_loss: 0.4081 - val_mean_absolute_error: 0.5223
# Epoch 14/40
# 53/53 [==============================] - 255s 5s/step - loss: 0.4259 - mean_absolute_error: 0.5352 - val_loss: 0.4127 - val_mean_absolute_error: 0.5219
# Epoch 15/40
# 53/53 [==============================] - 264s 5s/step - loss: 0.4214 - mean_absolute_error: 0.5311 - val_loss: 0.4029 - val_mean_absolute_error: 0.5174
# Epoch 16/40
# 53/53 [==============================] - 258s 5s/step - loss: 0.4166 - mean_absolute_error: 0.5275 - val_loss: 0.4052 - val_mean_absolute_error: 0.5174
# Epoch 17/40
# 53/53 [==============================] - 263s 5s/step - loss: 0.4154 - mean_absolute_error: 0.5280 - val_loss: 0.4038 - val_mean_absolute_error: 0.5161
# Epoch 18/40
# 53/53 [==============================] - 268s 5s/step - loss: 0.4116 - mean_absolute_error: 0.5240 - val_loss: 0.3979 - val_mean_absolute_error: 0.5111
# Epoch 19/40
# 53/53 [==============================] - 271s 5s/step - loss: 0.4086 - mean_absolute_error: 0.5208 - val_loss: 0.3950 - val_mean_absolute_error: 0.5098
# Epoch 20/40
# 53/53 [==============================] - 264s 5s/step - loss: 0.4101 - mean_absolute_error: 0.5208 - val_loss: 0.4028 - val_mean_absolute_error: 0.5157
# Epoch 21/40
# 53/53 [==============================] - 274s 5s/step - loss: 0.4041 - mean_absolute_error: 0.5174 - val_loss: 0.3965 - val_mean_absolute_error: 0.5104
# Epoch 22/40
# 53/53 [==============================] - 275s 5s/step - loss: 0.4070 - mean_absolute_error: 0.5200 - val_loss: 0.3918 - val_mean_absolute_error: 0.5073
# Epoch 23/40
# 53/53 [==============================] - 273s 5s/step - loss: 0.4007 - mean_absolute_error: 0.5149 - val_loss: 0.3974 - val_mean_absolute_error: 0.5102
# Epoch 24/40
# 53/53 [==============================] - 275s 5s/step - loss: 0.4008 - mean_absolute_error: 0.5144 - val_loss: 0.3861 - val_mean_absolute_error: 0.5017
# Epoch 25/40
# 53/53 [==============================] - 271s 5s/step - loss: 0.3999 - mean_absolute_error: 0.5128 - val_loss: 0.3886 - val_mean_absolute_error: 0.5041
# Epoch 26/40
# 53/53 [==============================] - 265s 5s/step - loss: 0.3948 - mean_absolute_error: 0.5097 - val_loss: 0.3835 - val_mean_absolute_error: 0.4993
# Epoch 27/40
# 53/53 [==============================] - 271s 5s/step - loss: 0.3927 - mean_absolute_error: 0.5086 - val_loss: 0.3839 - val_mean_absolute_error: 0.4999
# Epoch 28/40
# 53/53 [==============================] - 271s 5s/step - loss: 0.3933 - mean_absolute_error: 0.5085 - val_loss: 0.3860 - val_mean_absolute_error: 0.5013
# Epoch 29/40
# 53/53 [==============================] - 268s 5s/step - loss: 0.3910 - mean_absolute_error: 0.5058 - val_loss: 0.3804 - val_mean_absolute_error: 0.4969
# Epoch 30/40
# 53/53 [==============================] - 270s 5s/step - loss: 0.4002 - mean_absolute_error: 0.5123 - val_loss: 0.4028 - val_mean_absolute_error: 0.5076
# Epoch 31/40
# 53/53 [==============================] - 272s 5s/step - loss: 0.3910 - mean_absolute_error: 0.5069 - val_loss: 0.3900 - val_mean_absolute_error: 0.5033
# Epoch 32/40
# 53/53 [==============================] - 263s 5s/step - loss: 0.3873 - mean_absolute_error: 0.5014 - val_loss: 0.3769 - val_mean_absolute_error: 0.4934
# Epoch 33/40
# 53/53 [==============================] - 274s 5s/step - loss: 0.3924 - mean_absolute_error: 0.5062 - val_loss: 0.3791 - val_mean_absolute_error: 0.4939
# Epoch 34/40
# 53/53 [==============================] - 246s 5s/step - loss: 0.3855 - mean_absolute_error: 0.5008 - val_loss: 0.3756 - val_mean_absolute_error: 0.4928
# Epoch 35/40
# 53/53 [==============================] - 252s 5s/step - loss: 0.3819 - mean_absolute_error: 0.4987 - val_loss: 0.3911 - val_mean_absolute_error: 0.5034
# Epoch 36/40
# 53/53 [==============================] - 254s 5s/step - loss: 0.3912 - mean_absolute_error: 0.5036 - val_loss: 0.3726 - val_mean_absolute_error: 0.4894
# Epoch 37/40
# 53/53 [==============================] - 257s 5s/step - loss: 0.3819 - mean_absolute_error: 0.4972 - val_loss: 0.3719 - val_mean_absolute_error: 0.4888
# Epoch 38/40
# 53/53 [==============================] - 256s 5s/step - loss: 0.3789 - mean_absolute_error: 0.4965 - val_loss: 0.3802 - val_mean_absolute_error: 0.4950
# Epoch 39/40
# 53/53 [==============================] - 256s 5s/step - loss: 0.3885 - mean_absolute_error: 0.5002 - val_loss: 0.3958 - val_mean_absolute_error: 0.5018
# Epoch 40/40
# 53/53 [==============================] - 257s 5s/step - loss: 0.3778 - mean_absolute_error: 0.4955 - val_loss: 0.3713 - val_mean_absolute_error: 0.4869

# %%
plot_reg_history(f_history)

# %%
def predict_another_female(impath):
    img = facial_detection(impath, 10).resize((img_width, img_height))
    tensor = tf.image.convert_image_dtype(img, dtype=tf.float16, saturate=False, name=None)
    img_array = np.array([tensor])
    prediction = f_model.predict(img_array)
    prediction = float(prediction[0][0])
    print(f"This person is most likely a {round(prediction, 2)}")

    return img

# %%
def predict_scut_female(impath):
    img = PIL.Image.open(impath).resize((img_width, img_height))
    path = pathlib.Path(impath)
    index = f_test_images.index(path)
    f_actual_rating = f_test_ratings[index]
    
    tensor = tf.image.convert_image_dtype(img, dtype=tf.float16, saturate=False, name=None)
    img_array = np.array([tensor])
    prediction = f_model.predict(img_array)
    prediction = float(prediction[0][0])
    print(f"This person is most likely a {round(prediction, 2)}")
    print(f"Actual rating: {f_actual_rating}")

    return img

# %%
path = r"data/all_images_cropped/f_test/AF2.jpg"

f_img = predict_scut_female(path)
f_img
# Out:
# 1/1 [==============================] - 1s 794ms/step
# This person is most likely a 3.43
# Actual rating: 3.95
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
f_img = predict_another_female("data/my_images/kylie.jpg")
f_img
# Out:
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 210ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 252ms/step
# 1/1 [==============================] - 1s 891ms/step
# This person is most likely a 3.48
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# ## Results of Resnet Regression

# %% [markdown]
#     Generally, Resnet was able to predict attractiveness within ±0.45 of the actual facial rating (MAE 0.45) for both training and validation data. After 40 epochs, the best model was the specifically male-only resnet which achieved 0.44 and 0.43 MAE on the training and validation data respectively. The female-only model did the worst, which may be attributed to suboptimal starting weights for the model.
#
#     The models struggle witht the extremes, however, which is understandable since total (between both men AND women) there are only 16 training images total that round up to a 5 as opposed to 1,590 training images that round to a 3. A solution to this is data augmentation or gathering more data. Data augmentation with these images may be difficult due to all of the other images being upright and all of the faces being cropped to be in roughly the same place by MTCNN facial detection.
#
#     In addition, I believe that with more epochs, these models could reach 0.42 MAE or lower. I don't believe Resnet is the best option to achieve this, however. In hindsight, Resnet was not trained on faces, and therefore is not optimally extracting important facial features in it's convolutional layers. A solution to this would be extracting the image embeddings using Facenet or something similar, then performing regression separately. The underlying concept would still be transfer-learning, but Facenet would theoretically work better on faces.
#
#     Overall, I would consider the Resnet regression on the SCUT data a success. I learned how to use transfer-learning with Resnet to perform regression on data, as well as how to proceed to improve the results of regression on this dataset.

# %% [markdown]
# I'm choosing to only save the resnet model that was trained on both genders since it performed well on both and only slightly worse than the male-only model.

# %%
model.save("models/resnet_regression_both_44")
# Out:
# INFO:tensorflow:Assets written to: models/resnet_regression_both_44\assets
# INFO:tensorflow:Assets written to: models/resnet_regression_both_44\assets
